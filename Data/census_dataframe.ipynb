# %% [markdown]
# # U.S. Census Data: Male vs Female Did Not Work Rates

# %%
# Dependencies
import matplotlib.pyplot as plt
import requests
import pandas as pd
from census import Census
import us 
from scipy.stats import linregress
import scipy.stats as st
# Import U.S. Census API Key
from config import api_key

# %% [markdown]
# ## Retrieve data from the U.S. Census using the Census library
#
# References:
#
# https://api.census.gov/data/2017/acs/acs5/variables.html
#
#   NEEDED:
#
#   B23022_001E Estimate!!Total:
#   SEX BY WORK STATUS IN THE PAST 12 MONTHS BY USUAL HOURS WORKED PER WEEK IN THE PAST 12 MONTHS BY WEEKS WORKED IN THE PAST 12 MONTHS FOR THE POPULATION 16 TO 64 YEARS
#
#   B23001_088E Estimate!!Total:!!Female:
#   SEX BY AGE BY EMPLOYMENT STATUS FOR THE POPULATION 16 YEARS AND OVER
#
#   B23022_049E Estimate!!Total:!!Female:!!Did not work in the past 12 months
#   SEX BY WORK STATUS IN THE PAST 12 MONTHS BY USUAL HOURS WORKED PER WEEK IN THE PAST 12 MONTHS BY WEEKS WORKED IN THE PAST 12 MONTHS FOR THE POPULATION 16 TO 64 YEARS
#
#   B23022_002E Estimate!!Total:!!Male:
#   SEX BY WORK STATUS IN THE PAST 12 MONTHS BY USUAL HOURS WORKED PER WEEK IN THE PAST 12 MONTHS BY WEEKS WORKED IN THE PAST 12 MONTHS FOR THE POPULATION 16 TO 64 YEARS
#
#   B23022_025E Estimate!!Total:!!Male:!!Did not work in the past 12 months
#   SEX BY WORK STATUS IN THE PAST 12 MONTHS BY USUAL HOURS WORKED PER WEEK IN THE PAST 12 MONTHS BY WEEKS WORKED IN THE PAST 12 MONTHS FOR THE POPULATION 16 TO 64 YEARS

# %%
# Run Census Search to retrieve data on all zip codes (2013 ACS5 Census)

years = [2017,2018,2019,2020,2021]

for year in years:

    c = Census(
    api_key,
    year = year
              )
    
    census_data = c.acs5.get(
        (
            "NAME",
            "B19013_001E", #pop 
            "B01003_001E", #median age
            "B01002_001E", #household income
            "B19301_001E", #Per capital income
            "B17001_002E", #poverty count
            "B23022_001E", #total work force
            "B23001_088E", #total female workforce
            "B23022_049E", #total female did not work
            "B23022_002E", #total male workforce
            "B23022_025E", #total male did not work
            "B15003_023E", # masters degrees
            "B25058_001E", #median rent

            
        ), {'for': 'state:*', 'for': 'congressional district:*'}
    )


# # Convert to DataFrame, add the year of the census data, concatenate dfs together
    if year == years[0]:
        census_pd = pd.DataFrame(census_data)
        census_pd['Year'] = year
        census_pd_combined = census_pd
    else:
        census_pd = pd.DataFrame(census_data)
        census_pd['Year'] = year
        census_pd_combined = pd.concat([census_pd,census_pd_combined])

#Column renaming
census_pd_combined = census_pd_combined.rename(
    columns = {
        "NAME":        "Name",
        "B01003_001E": "Population",
        "B01002_001E": "Median Age",
        "B19013_001E": "Household Income",
        "B19301_001E": "Per Capita Income",
        "B17001_002E": "Poverty Count",
        "B23022_001E": "Total Work Force",
        "B23001_088E": "Total Female Workforce",
        "B23022_049E": "Total Female Did Not Work",
        "B23022_002E": "Total Male Workforce",
        "B23022_025E": "Total Male Did Not Work",
        "B15003_023E": "Masters Attainment",
        "B25058_001E": "Median Rent"
        
    }
        )

# %%
# Show Dataframe
census_pd_combined.head()
# Out:
#                                                 Name  Household Income  \
# 0  Congressional District 1 (116th Congress), Ala...           53606.0
# 1  Congressional District 2 (116th Congress), Ala...           52194.0
# 2  Congressional District 3 (116th Congress), Ala...           53090.0
# 3  Congressional District 4 (116th Congress), Ala...           50931.0
# 4  Congressional District 5 (116th Congress), Ala...           63180.0
#
#    Population  Median Age  Per Capita Income  Poverty Count  Total Work Force  \
# 0    722794.0        40.3            29688.0       109032.0          447518.0
# 1    689681.0        39.0            28319.0       115310.0          435275.0
# 2    731482.0        38.8            28451.0       121511.0          468161.0
# 3    702255.0        40.9            27056.0       109196.0          431360.0
# 4    751690.0        39.8            35350.0        90719.0          483297.0
#
#    Total Female Workforce  Total Female Did Not Work  Total Male Workforce  \
# 0                301800.0                    77217.0              217406.0
# 1                287843.0                    76285.0              213201.0
# 2                304646.0                    77313.0              230635.0
# 3                285978.0                    76826.0              216170.0
# 4                310448.0                    75739.0              241259.0
#
#    Total Male Did Not Work  Masters Attainment  Median Rent state  \
# 0                  55953.0             33551.0        707.0    01
# 1                  54707.0             31270.0        619.0    01
# 2                  57921.0             35868.0        590.0    01
# 3                  50766.0             24306.0        469.0    01
# 4                  48404.0             52340.0        643.0    01
#
#   congressional district  Year
# 0                     01  2021
# 1                     02  2021
# 2                     03  2021
# 3                     04  2021
# 4                     05  2021

# %%
# Add a Male Did Not Work Rate, Female Did Not Work Rate, Delta
census_pd_combined["Male DNW %"] = 100 * census_pd_combined["Total Male Did Not Work"] / census_pd_combined["Total Male Workforce"]
census_pd_combined["Female DNW %"] = 100 * census_pd_combined["Total Female Did Not Work"] / census_pd_combined["Total Female Workforce"]
census_pd_combined['DNW Delta'] = census_pd_combined['Female DNW %']-census_pd_combined['Male DNW %']
census_pd_combined['Poverty Rate'] = 100 * census_pd_combined["Poverty Count"] / census_pd_combined["Population"]

# Display DataFrame length and sample data

print(f"Number of rows in the DataFrame: {len(census_pd_combined)}")
census_pd_combined.head()
# Out:
# Number of rows in the DataFrame: 2197
#                                                 Name  Household Income  \
# 0  Congressional District 1 (116th Congress), Ala...           53606.0
# 1  Congressional District 2 (116th Congress), Ala...           52194.0
# 2  Congressional District 3 (116th Congress), Ala...           53090.0
# 3  Congressional District 4 (116th Congress), Ala...           50931.0
# 4  Congressional District 5 (116th Congress), Ala...           63180.0
#
#    Population  Median Age  Per Capita Income  Poverty Count  Total Work Force  \
# 0    722794.0        40.3            29688.0       109032.0          447518.0
# 1    689681.0        39.0            28319.0       115310.0          435275.0
# 2    731482.0        38.8            28451.0       121511.0          468161.0
# 3    702255.0        40.9            27056.0       109196.0          431360.0
# 4    751690.0        39.8            35350.0        90719.0          483297.0
#
#    Total Female Workforce  Total Female Did Not Work  Total Male Workforce  \
# 0                301800.0                    77217.0              217406.0
# 1                287843.0                    76285.0              213201.0
# 2                304646.0                    77313.0              230635.0
# 3                285978.0                    76826.0              216170.0
# 4                310448.0                    75739.0              241259.0
#
#    Total Male Did Not Work  Masters Attainment  Median Rent  state  \
# 0                  55953.0             33551.0        707.0      1
# 1                  54707.0             31270.0        619.0      1
# 2                  57921.0             35868.0        590.0      1
# 3                  50766.0             24306.0        469.0      1
# 4                  48404.0             52340.0        643.0      1
#
#   congressional district  Year  Male DNW %  Female DNW %  DNW Delta  \
# 0                     01  2021   25.736640     25.585487  -0.151153
# 1                     02  2021   25.659823     26.502295   0.842471
# 2                     03  2021   25.113708     25.377980   0.264272
# 3                     04  2021   23.484295     26.864304   3.380009
# 4                     05  2021   20.063086     24.396678   4.333593
#
#    Poverty Rate
# 0     15.084796
# 1     16.719324
# 2     16.611619
# 3     15.549337
# 4     12.068672

# %%
# Save the DataFrame as a CSV or read the dataframe

#census_pd_combined.to_csv("census_data.csv", encoding="utf-8", index=False)

#census_pd_combined = pd.read_csv("../Data/census_data.csv")

census_pd_combined
# Out:
#                                                    Name  Household Income  \
# 0     Congressional District 1 (116th Congress), Ala...           53606.0
# 1     Congressional District 2 (116th Congress), Ala...           52194.0
# 2     Congressional District 3 (116th Congress), Ala...           53090.0
# 3     Congressional District 4 (116th Congress), Ala...           50931.0
# 4     Congressional District 5 (116th Congress), Ala...           63180.0
# ...                                                 ...               ...
# 2192   Congressional District 2 (115th Congress), Texas           75989.0
# 2193   Congressional District 4 (115th Congress), Texas           51945.0
# 2194   Congressional District 8 (115th Congress), Texas           66893.0
# 2195  Congressional District 10 (115th Congress), Texas           72361.0
# 2196  Congressional District 13 (115th Congress), Texas           50854.0
#
#       Population  Median Age  Per Capita Income  Poverty Count  \
# 0       722794.0        40.3            29688.0       109032.0
# 1       689681.0        39.0            28319.0       115310.0
# 2       731482.0        38.8            28451.0       121511.0
# 3       702255.0        40.9            27056.0       109196.0
# 4       751690.0        39.8            35350.0        90719.0
# ...          ...         ...                ...            ...
# 2192    767312.0        35.3            40267.0        80005.0
# 2193    728435.0        39.2            26549.0       106074.0
# 2194    807525.0        36.7            33423.0        92583.0
# 2195    813505.0        35.5            35884.0        82145.0
# 2196    708616.0        35.8            25729.0       105505.0
#
#       Total Work Force  Total Female Workforce  Total Female Did Not Work  \
# 0             447518.0                301800.0                    77217.0
# 1             435275.0                287843.0                    76285.0
# 2             468161.0                304646.0                    77313.0
# 3             431360.0                285978.0                    76826.0
# 4             483297.0                310448.0                    75739.0
# ...                ...                     ...                        ...
# 2192          521305.0                301525.0                    73161.0
# 2193          450290.0                291712.0                    74141.0
# 2194          521633.0                307296.0                    87872.0
# 2195          533905.0                316616.0                    73838.0
# 2196          446467.0                271008.0                    62159.0
#
#       Total Male Workforce  Total Male Did Not Work  Masters Attainment  \
# 0                 217406.0                  55953.0             33551.0
# 1                 213201.0                  54707.0             31270.0
# 2                 230635.0                  57921.0             35868.0
# 3                 216170.0                  50766.0             24306.0
# 4                 241259.0                  48404.0             52340.0
# ...                    ...                      ...                 ...
# 2192              264826.0                  36673.0             53472.0
# 2193              224333.0                  49427.0             25744.0
# 2194              269763.0                  64112.0             37782.0
# 2195              268328.0                  38118.0             51083.0
# 2196              232897.0                  49474.0             20682.0
#
#       Median Rent  state congressional district  Year  Male DNW %  \
# 0           707.0      1                     01  2021   25.736640
# 1           619.0      1                     02  2021   25.659823
# 2           590.0      1                     03  2021   25.113708
# 3           469.0      1                     04  2021   23.484295
# 4           643.0      1                     05  2021   20.063086
# ...           ...    ...                    ...   ...         ...
# 2192        993.0     48                     02  2017   13.847961
# 2193        601.0     48                     04  2017   22.032871
# 2194        864.0     48                     08  2017   23.766046
# 2195        935.0     48                     10  2017   14.205748
# 2196        607.0     48                     13  2017   21.242867
#
#       Female DNW %  DNW Delta
# 0        25.585487  -0.151153
# 1        26.502295   0.842471
# 2        25.377980   0.264272
# 3        26.864304   3.380009
# 4        24.396678   4.333593
# ...            ...        ...
# 2192     24.263660  10.415699
# 2193     25.415821   3.382950
# 2194     28.595231   4.829184
# 2195     23.320995   9.115246
# 2196     22.936223   1.693356
#
# [2197 rows x 19 columns]

# %%
#Split the name column into congressional district and state
census_pd_combined[['Congressional District Name','State Name']] = census_pd_combined['Name'].str.split(',',expand=True)
census_pd_combined['Congressional District Name'].str.replace(' ', '') 
census_pd_combined['State Name'].str.replace(' ', '') 
census_pd_combined.head()
# Out:
#                                                 Name  Household Income  \
# 0  Congressional District 1 (116th Congress), Ala...           53606.0
# 1  Congressional District 2 (116th Congress), Ala...           52194.0
# 2  Congressional District 3 (116th Congress), Ala...           53090.0
# 3  Congressional District 4 (116th Congress), Ala...           50931.0
# 4  Congressional District 5 (116th Congress), Ala...           63180.0
#
#    Population  Median Age  Per Capita Income  Poverty Count  Total Work Force  \
# 0    722794.0        40.3            29688.0       109032.0          447518.0
# 1    689681.0        39.0            28319.0       115310.0          435275.0
# 2    731482.0        38.8            28451.0       121511.0          468161.0
# 3    702255.0        40.9            27056.0       109196.0          431360.0
# 4    751690.0        39.8            35350.0        90719.0          483297.0
#
#    Total Female Workforce  Total Female Did Not Work  Total Male Workforce  \
# 0                301800.0                    77217.0              217406.0
# 1                287843.0                    76285.0              213201.0
# 2                304646.0                    77313.0              230635.0
# 3                285978.0                    76826.0              216170.0
# 4                310448.0                    75739.0              241259.0
#
#    ...  Median Rent  state  congressional district  Year Male DNW %  \
# 0  ...        707.0      1                      01  2021  25.736640
# 1  ...        619.0      1                      02  2021  25.659823
# 2  ...        590.0      1                      03  2021  25.113708
# 3  ...        469.0      1                      04  2021  23.484295
# 4  ...        643.0      1                      05  2021  20.063086
#
#    Female DNW %  DNW Delta  Poverty Rate  \
# 0     25.585487  -0.151153     15.084796
# 1     26.502295   0.842471     16.719324
# 2     25.377980   0.264272     16.611619
# 3     26.864304   3.380009     15.549337
# 4     24.396678   4.333593     12.068672
#
#                  Congressional District Name  State Name
# 0  Congressional District 1 (116th Congress)     Alabama
# 1  Congressional District 2 (116th Congress)     Alabama
# 2  Congressional District 3 (116th Congress)     Alabama
# 3  Congressional District 4 (116th Congress)     Alabama
# 4  Congressional District 5 (116th Congress)     Alabama
#
# [5 rows x 22 columns]

# %%
#Summary Statistics for Male & Female DNW Rates, Disparity, Poverty Rates by year 

census_pd_combined_groupby = census_pd_combined.groupby(['Year'],as_index= False)
census_pd_combined_groupby.agg(['mean'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1871, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1870 try:
# -> 1871     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1872 except Exception as err:
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# --> 871     res = func(group)
#     872     res = extract_result(res)
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:2377, in GroupBy.mean.<locals>.<lambda>(x)
#    2374 else:
#    2375     result = self._cython_agg_general(
#    2376         "mean",
# -> 2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\series.py:6221, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6213 @doc(make_doc("mean", ndim=1))
#    6214 def mean(
#    6215     self,
#    (...)
#    6219     **kwargs,
#    6220 ):
# -> 6221     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\generic.py:11978, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11971 def mean(
#   11972     self,
#   11973     axis: Axis | None = 0,
#    (...)
#   11976     **kwargs,
#   11977 ) -> Series | float:
# > 11978     return self._stat_function(
#   11979         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11980     )
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\generic.py:11935, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11933 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11935 return self._reduce(
#   11936     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11937 )
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\series.py:6129, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6125     raise TypeError(
#    6126         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6127         "with non-numeric dtypes."
#    6128     )
# -> 6129 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string 'Congressional District 1 (115th Congress), New JerseyCongressional District 2 (115th Congress), New JerseyCongressional District 4 (115th Congress), New JerseyCongressional District 5 (115th Congress), New JerseyCongressional District 6 (115th Congress), New JerseyCongressional District 7 (115th Congress), New JerseyCongressional District 8 (115th Congress), New JerseyCongressional District 9 (115th Congress), New JerseyCongressional District 10 (115th Congress), New JerseyCongressional District 11 (115th Congress), New JerseyCongressional District 12 (115th Congress), New JerseyCongressional District 2 (115th Congress), New MexicoCongressional District 3 (115th Congress), New MexicoCongressional District 1 (115th Congress), New YorkCongressional District 3 (115th Congress), New YorkCongressional District 5 (115th Congress), New YorkCongressional District 6 (115th Congress), New YorkCongressional District 8 (115th Congress), New YorkCongressional District 10 (115th Congress), New YorkCongressional District 11 (115th Congress), New YorkCongressional District 13 (115th Congress), New YorkCongressional District 15 (115th Congress), New YorkCongressional District 16 (115th Congress), New YorkCongressional District 18 (115th Congress), New YorkCongressional District 20 (115th Congress), New YorkCongressional District 21 (115th Congress), New YorkCongressional District 23 (115th Congress), New YorkCongressional District 25 (115th Congress), New YorkCongressional District 26 (115th Congress), New YorkCongressional District 6 (115th Congress), TexasCongressional District 1 (115th Congress), TexasCongressional District 3 (115th Congress), TexasCongressional District 5 (115th Congress), TexasCongressional District 7 (115th Congress), TexasCongressional District 9 (115th Congress), TexasCongressional District 11 (115th Congress), TexasCongressional District 12 (115th Congress), TexasCongressional District 14 (115th Congress), TexasCongressional District 16 (115th Congress), TexasCongressional District 17 (115th Congress), TexasCongressional District 19 (115th Congress), TexasCongressional District 21 (115th Congress), TexasCongressional District 22 (115th Congress), TexasCongressional District 24 (115th Congress), TexasCongressional District 26 (115th Congress), TexasCongressional District 28 (115th Congress), TexasCongressional District 29 (115th Congress), TexasCongressional District 31 (115th Congress), TexasCongressional District 33 (115th Congress), TexasCongressional District 34 (115th Congress), TexasCongressional District 36 (115th Congress), TexasCongressional District (at Large) (115th Congress), VermontCongressional District 4 (115th Congress), UtahCongressional District 1 (115th Congress), UtahCongressional District 3 (115th Congress), UtahCongressional District 1 (115th Congress), VirginiaCongressional District 2 (115th Congress), VirginiaCongressional District 4 (115th Congress), VirginiaCongressional District 6 (115th Congress), VirginiaCongressional District 7 (115th Congress), VirginiaCongressional District 9 (115th Congress), VirginiaCongressional District 1 (115th Congress), North CarolinaCongressional District 2 (115th Congress), North CarolinaCongressional District 3 (115th Congress), North CarolinaCongressional District 4 (115th Congress), North CarolinaCongressional District 5 (115th Congress), North CarolinaCongressional District 6 (115th Congress), North CarolinaCongressional District 7 (115th Congress), North CarolinaCongressional District 8 (115th Congress), North CarolinaCongressional District 10 (115th Congress), North CarolinaCongressional District 12 (115th Congress), North CarolinaCongressional District 13 (115th Congress), North CarolinaCongressional District (at Large) (115th Congress), North DakotaCongressional District 7 (115th Congress), OhioCongressional District 8 (115th Congress), OhioCongressional District 10 (115th Congress), OhioCongressional District 12 (115 ...
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\natha\OneDrive\Documents\UCI Bootcamp\Project_1\Nathan_Analysis\Data\census_dataframe.ipynb Cell 9 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/natha/OneDrive/Documents/UCI%20Bootcamp/Project_1/Nathan_Analysis/Data/census_dataframe.ipynb#X21sZmlsZQ%3D%3D?line=0'>1</a> #Summary Statistics for Male & Female DNW Rates, Disparity, Poverty Rates by year
#       <a href='vscode-notebook-cell:/c%3A/Users/natha/OneDrive/Documents/UCI%20Bootcamp/Project_1/Nathan_Analysis/Data/census_dataframe.ipynb#X21sZmlsZQ%3D%3D?line=2'>3</a> census_pd_combined_groupby = census_pd_combined.groupby(['Year'],as_index= False)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/natha/OneDrive/Documents/UCI%20Bootcamp/Project_1/Nathan_Analysis/Data/census_dataframe.ipynb#X21sZmlsZQ%3D%3D?line=3'>4</a> census_pd_combined_groupby.agg(['mean'])
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1442, in DataFrameGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#    1439     kwargs["engine_kwargs"] = engine_kwargs
#    1441 op = GroupByApply(self, func, args=args, kwargs=kwargs)
# -> 1442 result = op.agg()
#    1443 if not is_dict_like(func) and result is not None:
#    1444     # GH #52849
#    1445     if not self.as_index and is_list_like(func):
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\apply.py:178, in Apply.agg(self)
#     175     return self.agg_dict_like()
#     176 elif is_list_like(func):
#     177     # we require a list, but not a 'str'
# --> 178     return self.agg_list_like()
#     180 if callable(func):
#     181     f = com.get_cython_func(func)
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\apply.py:311, in Apply.agg_list_like(self)
#     303 def agg_list_like(self) -> DataFrame | Series:
#     304     """
#     305     Compute aggregation in the case of a list-like argument.
#     306
#    (...)
#     309     Result of aggregation.
#     310     """
# --> 311     return self.agg_or_apply_list_like(op_name="agg")
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\apply.py:1351, in GroupByApply.agg_or_apply_list_like(self, op_name)
#    1346 # Only set as_index=True on groupby objects, not Window or Resample
#    1347 # that inherit from this class.
#    1348 with com.temp_setattr(
#    1349     obj, "as_index", True, condition=hasattr(obj, "as_index")
#    1350 ):
# -> 1351     keys, results = self.compute_list_like(op_name, selected_obj, kwargs)
#    1352 result = self.wrap_results_list_like(keys, results)
#    1353 return result
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\apply.py:370, in Apply.compute_list_like(self, op_name, selected_obj, kwargs)
#     364 colg = obj._gotitem(col, ndim=1, subset=selected_obj.iloc[:, index])
#     365 args = (
#     366     [self.axis, *self.args]
#     367     if include_axis(op_name, colg)
#     368     else self.args
#     369 )
# --> 370 new_res = getattr(colg, op_name)(func, *args, **kwargs)
#     371 results.append(new_res)
#     372 indices.append(index)
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:252, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     250 kwargs["engine"] = engine
#     251 kwargs["engine_kwargs"] = engine_kwargs
# --> 252 ret = self._aggregate_multiple_funcs(func, *args, **kwargs)
#     253 if relabeling:
#     254     # columns is not narrowed by mypy from relabeling flag
#     255     assert columns is not None  # for mypy
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:357, in SeriesGroupBy._aggregate_multiple_funcs(self, arg, *args, **kwargs)
#     355     for idx, (name, func) in enumerate(arg):
#     356         key = base.OutputKey(label=name, position=idx)
# --> 357         results[key] = self.aggregate(func, *args, **kwargs)
#     359 if any(isinstance(x, DataFrame) for x in results.values()):
#     360     from pandas import concat
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:244, in SeriesGroupBy.aggregate(self, func, engine, engine_kwargs, *args, **kwargs)
#     242         kwargs["engine"] = engine
#     243         kwargs["engine_kwargs"] = engine_kwargs
# --> 244     return getattr(self, func)(*args, **kwargs)
#     246 elif isinstance(func, abc.Iterable):
#     247     # Catch instances of lists / tuples
#     248     # but not the class list / tuple itself.
#     249     func = maybe_mangle_lambdas(func)
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:2375, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2368     return self._numba_agg_general(
#    2369         grouped_mean,
#    2370         executor.float_dtype_mapping,
#    2371         engine_kwargs,
#    2372         min_periods=0,
#    2373     )
#    2374 else:
# -> 2375     result = self._cython_agg_general(
#    2376         "mean",
#    2377         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2378         numeric_only=numeric_only,
#    2379     )
#    2380     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1926, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1923     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924     return result
# -> 1926 new_mgr = data.grouped_reduce(array_func)
#    1927 res = self._wrap_agged_manager(new_mgr)
#    1928 out = self._wrap_aggregated_output(res)
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\internals\base.py:336, in SingleDataManager.grouped_reduce(self, func)
#     334 def grouped_reduce(self, func):
#     335     arr = self.array
# --> 336     res = func(arr)
#     337     index = default_index(len(res))
#     339     mgr = type(self).from_array(res, index)
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1923, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1920 else:
#    1921     return result
# -> 1923 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1924 return result
#
# File c:\Users\natha\anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:1875, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1874     # preserve the kind of exception that raised
# -> 1875     raise type(err)(msg) from err
#    1877 if ser.dtype == object:
#    1878     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
# Build the scatter plots for DNW & State
census_data_2021 = census_pd_combined.loc[census_pd_combined['Year'] == 2021]
census_pd_combined_groupby = census_data_2021.groupby(['State Name'],as_index= False)
census_pd_combined_mean = census_pd_combined_groupby['DNW Delta'].mean()
census_pd_combined_mean_df = pd.DataFrame(census_pd_combined_mean)
census_pd_combined_mean_df

title = 'State vs. Did Not Work Disparity in 2021'
xlabel = 'State'
ylabel = 'Gender Did Not Work Disparity'
census_pd_combined_mean_df.plot.scatter(x = 'State Name', y = 'DNW Delta', title = title, xlabel = xlabel, ylabel = ylabel,figsize=(17.5,5),rot = 90)
# Out:
# <Axes: title={'center': 'State vs. Did Not Work Disparity in 2021'}, xlabel='State', ylabel='Gender Did Not Work Disparity'>

# %%
# Build the scatter plots for all states Over Time

census_pd_combined_groupby = census_pd_combined.groupby(['Year'],as_index= False)
census_pd_combined_mean = census_pd_combined_groupby['DNW Delta'].mean()
census_pd_combined_mean_df = pd.DataFrame(census_pd_combined_mean)
census_pd_combined_mean_df['Year'] = census_pd_combined_mean_df['Year'].astype(str)

title = 'Year vs. Did Not Work Disparity'
xlabel = 'Year'
ylabel = 'Gender Did Not Work Disparity'
census_pd_combined_mean_df.plot.line(x = 'Year', y = 'DNW Delta', title = title, xlabel = xlabel, ylabel = ylabel,figsize=(5,5),rot = 90)

census_pd_combined_mean_df
# Out:
#    Year  DNW Delta
# 0  2017   2.287976
# 1  2018   2.179029
# 2  2019   2.022752
# 3  2020   1.696207
# 4  2021   1.542475

# %%
# Build the Male DNW rate Over Time

census_pd_combined_groupby = census_pd_combined.groupby(['Year'],as_index= False)
census_pd_combined_mean = census_pd_combined_groupby['Male DNW %'].mean()
census_pd_combined_mean_df = pd.DataFrame(census_pd_combined_mean)
census_pd_combined_mean_df['Year'] = census_pd_combined_mean_df['Year'].astype(str)

title = 'Year vs. Male DNW %'
xlabel = 'Year'
ylabel = 'Male Did Not Work'
census_pd_combined_mean_df.plot.line(x = 'Year', y = 'Male DNW %', title = title, xlabel = xlabel, ylabel = ylabel,figsize=(5,5),rot = 90)

census_pd_combined_mean_df
# Out:
#    Year  Male DNW %
# 0  2017   20.299687
# 1  2018   19.866003
# 2  2019   19.454958
# 3  2020   19.094418
# 4  2021   19.252077

# %%
# Build the Female DNW rate Over Time

census_pd_combined_groupby = census_pd_combined.groupby(['Year'],as_index= False)
census_pd_combined_mean = census_pd_combined_groupby['Female DNW %'].mean()
census_pd_combined_mean_df = pd.DataFrame(census_pd_combined_mean)
census_pd_combined_mean_df['Year'] = census_pd_combined_mean_df['Year'].astype(str)

title = 'Year vs. Female DNW %'
xlabel = 'Year'
ylabel = 'Female Did Not Work'
census_pd_combined_mean_df.plot.line(x = 'Year', y = 'Female DNW %', title = title, xlabel = xlabel, ylabel = ylabel,figsize=(5,5),rot = 90)

census_pd_combined_mean_df
# Out:
#    Year  Female DNW %
# 0  2017     22.587664
# 1  2018     22.045032
# 2  2019     21.477710
# 3  2020     20.790625
# 4  2021     20.794552

# %%
# Build the scatter plots for all states Over Time (poverty rate)
census_pd_combined_groupby = census_pd_combined.groupby(['Year'],as_index= False)
census_pd_combined_mean = census_pd_combined_groupby['Poverty Rate'].mean()
census_pd_combined_mean_df = pd.DataFrame(census_pd_combined_mean)
census_pd_combined_mean_df['Year'] = census_pd_combined_mean_df['Year'].astype(str)

title = 'Poverty Rate by Year'
xlabel = 'Year'
ylabel = 'Poverty Rate'
census_pd_combined_mean_df.plot.line(x = 'Year', y = 'Poverty Rate', title = title, xlabel = xlabel, ylabel = ylabel,figsize=(5,5),rot = 90)

census_pd_combined_mean_df
# Out:
#    Year  Poverty Rate
# 0  2017     14.315516
# 1  2018     13.811113
# 2  2019     13.208590
# 3  2020     12.652172
# 4  2021     12.475131

# %%
# Build the scatter plots Utah

census_pd_combined['State Name'].values


census_pd_combined_utah = census_pd_combined.loc[census_pd_combined['State Name'] == ' Utah']
census_pd_combined_utah
census_pd_combined_groupby = census_pd_combined_utah.groupby(['Year'],as_index= False)
census_pd_combined_mean = census_pd_combined_groupby['DNW Delta'].mean()
census_pd_combined_mean_df = pd.DataFrame(census_pd_combined_mean)
census_pd_combined_mean_df['Year'] = census_pd_combined_mean_df['Year'].astype(str)

census_pd_combined_mean_df

title = 'Utah Unemployment Disparity'
xlabel = 'State'
ylabel = 'Gender Unemployment Disparity'
census_pd_combined_mean_df.plot.line(x = 'Year', y = 'DNW Delta', title = title, xlabel = xlabel, ylabel = ylabel,figsize=(5,5),rot = 90)
# Out:
# <Axes: title={'center': 'Utah Unemployment Disparity'}, xlabel='State', ylabel='Gender Unemployment Disparity'>

# %%
# Build the scatter plots Texas

census_pd_combined['State Name'].values


census_pd_combined_utah = census_pd_combined.loc[census_pd_combined['State Name'] == ' Texas']
census_pd_combined_utah
census_pd_combined_groupby = census_pd_combined_utah.groupby(['Year'],as_index= False)
census_pd_combined_mean = census_pd_combined_groupby['DNW Delta'].mean()
census_pd_combined_mean_df = pd.DataFrame(census_pd_combined_mean)
census_pd_combined_mean_df['Year'] = census_pd_combined_mean_df['Year'].astype(str)

census_pd_combined_mean_df

title = 'Texas Unemployment Disparity'
xlabel = 'State'
ylabel = 'Gender Unemployment Disparity'
census_pd_combined_mean_df.plot.scatter(x = 'Year', y = 'DNW Delta', title = title, xlabel = xlabel, ylabel = ylabel,figsize=(5,5),rot = 90)
# Out:
# <Axes: title={'center': 'Texas Unemployment Disparity'}, xlabel='State', ylabel='Gender Unemployment Disparity'>

# %%
# Build the scatter plots CA

census_pd_combined['State Name'].values


census_pd_combined_utah = census_pd_combined.loc[census_pd_combined['State Name'] == ' California']
census_pd_combined_utah
census_pd_combined_groupby = census_pd_combined_utah.groupby(['Year'],as_index= False)
census_pd_combined_mean = census_pd_combined_groupby['DNW Delta'].mean()
census_pd_combined_mean_df = pd.DataFrame(census_pd_combined_mean)
census_pd_combined_mean_df['Year'] = census_pd_combined_mean_df['Year'].astype(str)

census_pd_combined_mean_df

title = 'CA Unemployment Disparity'
xlabel = 'State'
ylabel = 'Gender Unemployment Disparity'
census_pd_combined_mean_df.plot.scatter(x = 'Year', y = 'DNW Delta', title = title, xlabel = xlabel, ylabel = ylabel,figsize=(5,5),rot = 90)
# Out:
# <Axes: title={'center': 'CA Unemployment Disparity'}, xlabel='State', ylabel='Gender Unemployment Disparity'>

# %%
# Build the scatter plots disparity vs poverty

census_pd_combined_nonull = census_pd_combined.dropna()

title = 'Poverty Rate vs. Did Not Work Disparity in 2021'
xlabel = 'Disparity'
ylabel = 'Poverty Rate'
census_pd_combined_nonull.plot.scatter(x = 'Poverty Rate', y = 'DNW Delta', title = title, xlabel = xlabel, ylabel = ylabel,figsize=(15,5),rot = 90)



x_values = census_pd_combined_nonull['Poverty Rate']
y_values = census_pd_combined_nonull['DNW Delta']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Poverty Rate')
plt.ylabel('DNW Delta')
plt.show()

print(f'The p value of {pvalue} means we can reject the Hnull, and conclude that there is a significant relationship between unemployment disparity and poverty rates')
# Out:
# The p value of 2.1639120516309905e-40 means we can reject the Hnull, and conclude that there is a significant relationship between unemployment disparity and poverty rates
