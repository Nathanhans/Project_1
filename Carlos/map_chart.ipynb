# %%
# Map of the US that color codes disparity in unemployment rates

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
import matplotlib.colors as mcolors
import seaborn as sns
import geopandas as gpd
from shapely.geometry import Polygon
import missingno as msno
import os
import wget
import openpyxl
import math
import fiona
from census import Census
import us 
from scipy.stats import linregress
import scipy.stats as st
# Import U.S. Census API Key
from config import api_key

# %%
#wget.download("https://www2.census.gov/geo/tiger/GENZ2018/shp/cb_2018_us_state_500k.zip") GET SHAPEFILE

shapefile = fiona.open("cb_2018_us_state_500k/cb_2018_us_state_500k.shp")
shapefile_df = pd.DataFrame(shapefile)
#create key
shapefile_df['state_code'] = shapefile_df['id'].astype(int)
shapefile_df.head()
# Out:
#                           geometry id  \
# 0  [coordinates, type, geometries]  0
# 1  [coordinates, type, geometries]  1
# 2  [coordinates, type, geometries]  2
# 3  [coordinates, type, geometries]  3
# 4  [coordinates, type, geometries]  4
#
#                                           properties  state_code
# 0  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...           0
# 1  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...           1
# 2  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...           2
# 3  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...           3
# 4  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...           4

# %%
#GET STATE ONLY INFO FROM CENSUS

years = [2021]

for year in years:

    c = Census(
    api_key,
    year = year
              )
    
    census_data = c.acs5.get(
        (
            "NAME",
            "B19013_001E", #pop 
            "B01003_001E", #median age
            "B01002_001E", #household income
            "B19301_001E", #Per capital income
            "B17001_002E", #poverty count
            "B23022_001E", #total work force
            "B23001_088E", #total female workforce
            "B23022_049E", #total female did not work
            "B23022_002E", #total male workforce
            "B23022_025E", #total male did not work
            "B15003_023E", # masters degrees
            "B25058_001E", #median rent

            
        ), {'for': 'state:*'}
    )


# # Convert to DataFrame, add the year of the census data, concatenate dfs together
    if year == years[0]:
        census_pd = pd.DataFrame(census_data)
        census_pd['Year'] = year
        census_pd_combined = census_pd
    else:
        census_pd = pd.DataFrame(census_data)
        census_pd['Year'] = year
        census_pd_combined = pd.concat([census_pd,census_pd_combined])

#Column renaming
census_pd_combined = census_pd_combined.rename(
    columns = {
        "NAME":        "Name",
        "B01003_001E": "Population",
        "B01002_001E": "Median Age",
        "B19013_001E": "Household Income",
        "B19301_001E": "Per Capita Income",
        "B17001_002E": "Poverty Count",
        "B23022_001E": "Total Work Force",
        "B23001_088E": "Total Female Workforce",
        "B23022_049E": "Total Female Did Not Work",
        "B23022_002E": "Total Male Workforce",
        "B23022_025E": "Total Male Did Not Work",
        "B15003_023E": "Masters Attainment",
        "B25058_001E": "Median Rent"
        
    }
        )

# %%
#Merge Datasets

#create key
census_pd_combined['state_code'] = census_pd_combined['state'].astype(int)
census_pd_combined.head()

#merge
census_pd_combined_shape = pd.merge(census_pd_combined, shapefile_df, how = 'left', on='state_code')
census_pd_combined_shape.head()
# Out:
#          Name  Household Income  Population  Median Age  Per Capita Income  \
# 0     Alabama           54943.0   4997675.0        39.3            30458.0
# 1      Alaska           80287.0    735951.0        35.0            39236.0
# 2     Arizona           65913.0   7079203.0        38.1            34644.0
# 3    Arkansas           52123.0   3006309.0        38.3            29210.0
# 4  California           84097.0  39455353.0        37.0            41276.0
#
#    Poverty Count  Total Work Force  Total Female Workforce  \
# 0       769819.0         3161072.0               2083785.0
# 1        75016.0          481977.0                271261.0
# 2       934911.0         4406765.0               2846006.0
# 3       468113.0         1876894.0               1219539.0
# 4      4741175.0        25829825.0              15857294.0
#
#    Total Female Did Not Work  Total Male Workforce  Total Male Did Not Work  \
# 0                   524779.0             1549575.0                 371362.0
# 1                    54983.0              255877.0                  43700.0
# 2                   634233.0             2227680.0                 444809.0
# 3                   287362.0              935991.0                 232365.0
# 4                  3798202.0            13092884.0                2633897.0
#
#    Masters Attainment  Median Rent state  Year  state_code  \
# 0            251040.0        630.0    01  2021           1
# 1             39503.0       1153.0    02  2021           2
# 2            413353.0        994.0    04  2021           4
# 3            129009.0        612.0    05  2021           5
# 4           2449563.0       1547.0    06  2021           6
#
#                           geometry id  \
# 0  [coordinates, type, geometries]  1
# 1  [coordinates, type, geometries]  2
# 2  [coordinates, type, geometries]  4
# 3  [coordinates, type, geometries]  5
# 4  [coordinates, type, geometries]  6
#
#                                           properties
# 0  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...
# 1  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...
# 2  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...
# 3  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...
# 4  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...

# %%
# Add a Male Did Not Work Rate, Female Did Not Work Rate, Delta
census_pd_combined_shape["Male DNW %"] = 100 * census_pd_combined_shape["Total Male Did Not Work"] / census_pd_combined_shape["Total Male Workforce"]
census_pd_combined_shape["Female DNW %"] = 100 * census_pd_combined_shape["Total Female Did Not Work"] / census_pd_combined_shape["Total Female Workforce"]
census_pd_combined_shape['DNW Delta'] = census_pd_combined_shape['Female DNW %']-census_pd_combined_shape['Male DNW %']
census_pd_combined_shape['Poverty Rate'] = 100 * census_pd_combined_shape["Poverty Count"] / census_pd_combined_shape["Population"]

# Display DataFrame length and sample data

print(f"Number of rows in the DataFrame: {len(census_pd_combined_shape)}")
census_pd_combined_shape.head()
# Out:
# Number of rows in the DataFrame: 52
#          Name  Household Income  Population  Median Age  Per Capita Income  \
# 0     Alabama           54943.0   4997675.0        39.3            30458.0
# 1      Alaska           80287.0    735951.0        35.0            39236.0
# 2     Arizona           65913.0   7079203.0        38.1            34644.0
# 3    Arkansas           52123.0   3006309.0        38.3            29210.0
# 4  California           84097.0  39455353.0        37.0            41276.0
#
#    Poverty Count  Total Work Force  Total Female Workforce  \
# 0       769819.0         3161072.0               2083785.0
# 1        75016.0          481977.0                271261.0
# 2       934911.0         4406765.0               2846006.0
# 3       468113.0         1876894.0               1219539.0
# 4      4741175.0        25829825.0              15857294.0
#
#    Total Female Did Not Work  Total Male Workforce  ...  state  Year  \
# 0                   524779.0             1549575.0  ...     01  2021
# 1                    54983.0              255877.0  ...     02  2021
# 2                   634233.0             2227680.0  ...     04  2021
# 3                   287362.0              935991.0  ...     05  2021
# 4                  3798202.0            13092884.0  ...     06  2021
#
#    state_code                         geometry  id  \
# 0           1  [coordinates, type, geometries]   1
# 1           2  [coordinates, type, geometries]   2
# 2           4  [coordinates, type, geometries]   4
# 3           5  [coordinates, type, geometries]   5
# 4           6  [coordinates, type, geometries]   6
#
#                                           properties Male DNW % Female DNW %  \
# 0  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...  23.965410    25.183932
# 1  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...  17.078518    20.269408
# 2  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...  19.967365    22.285020
# 3  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...  24.825559    23.563166
# 4  [STATEFP, STATENS, AFFGEOID, GEOID, STUSPS, NA...  20.117012    23.952397
#
#   DNW Delta  Poverty Rate
# 0  1.218522     15.403543
# 1  3.190890     10.193070
# 2  2.317655     13.206444
# 3 -1.262393     15.571021
# 4  3.835385     12.016557
#
# [5 rows x 23 columns]

# %%
# code source https://www.datacamp.com/tutorial/making-map-in-python-using-plotly-library-guide

# I am having trouble w/hover_name 

import plotly.express as px
import pandas as pd


# Import data from csv
data = pd.read_csv('../Carlos/census_data_states.csv')


# Create basic choropleth map
fig = px.choropleth(data, locations='iso_alpha', color='gdpPercap', hover_name='State',
                    projection='natural earth', animation_frame='year',
                    title='disparity in unemployment rates: states')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/carlosaraujo/Desktop/DataClass/Project_1/Carlos/map_chart.ipynb Cell 7 line 1
#       <a href='vscode-notebook-cell:/Users/carlosaraujo/Desktop/DataClass/Project_1/Carlos/map_chart.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a> data = pd.read_csv('../Carlos/census_data_states.csv')
#      <a href='vscode-notebook-cell:/Users/carlosaraujo/Desktop/DataClass/Project_1/Carlos/map_chart.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a> # Create basic choropleth map
# ---> <a href='vscode-notebook-cell:/Users/carlosaraujo/Desktop/DataClass/Project_1/Carlos/map_chart.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a> fig = px.choropleth(data, locations='iso_alpha', color='gdpPercap', hover_name='State',
#      <a href='vscode-notebook-cell:/Users/carlosaraujo/Desktop/DataClass/Project_1/Carlos/map_chart.ipynb#W6sZmlsZQ%3D%3D?line=12'>13</a>                     projection='natural earth', animation_frame='year',
#      <a href='vscode-notebook-cell:/Users/carlosaraujo/Desktop/DataClass/Project_1/Carlos/map_chart.ipynb#W6sZmlsZQ%3D%3D?line=13'>14</a>                     title='disparity in unemployment rates: states')
#      <a href='vscode-notebook-cell:/Users/carlosaraujo/Desktop/DataClass/Project_1/Carlos/map_chart.ipynb#W6sZmlsZQ%3D%3D?line=14'>15</a> fig.show()
#
# File ~/anaconda3/lib/python3.11/site-packages/plotly/express/_chart_types.py:1091, in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#    1051 def choropleth(
#    1052     data_frame=None,
#    1053     lat=None,
#    (...)
#    1085     height=None,
#    1086 ) -> go.Figure:
#    1087     """
#    1088     In a choropleth map, each row of `data_frame` is represented by a
#    1089     colored region mark on a map.
#    1090     """
# -> 1091     return make_figure(
#    1092         args=locals(),
#    1093         constructor=go.Choropleth,
#    1094         trace_patch=dict(locationmode=locationmode),
#    1095     )
#
# File ~/anaconda3/lib/python3.11/site-packages/plotly/express/_core.py:1990, in make_figure(args, constructor, trace_patch, layout_patch)
#    1987 layout_patch = layout_patch or {}
#    1988 apply_default_cascade(args)
# -> 1990 args = build_dataframe(args, constructor)
#    1991 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    1992     args = process_dataframe_hierarchy(args)
#
# File ~/anaconda3/lib/python3.11/site-packages/plotly/express/_core.py:1405, in build_dataframe(args, constructor)
#    1402     args["color"] = None
#    1403 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1405 df_output, wide_id_vars = process_args_into_dataframe(
#    1406     args, wide_mode, var_name, value_name
#    1407 )
#    1409 # now that `df_output` exists and `args` contains only references, we complete
#    1410 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1411 # df_output
#    1413 count_name = _escape_col_name(df_output, "count", [var_name, value_name])
#
# File ~/anaconda3/lib/python3.11/site-packages/plotly/express/_core.py:1207, in process_args_into_dataframe(args, wide_mode, var_name, value_name)
#    1205         if argument == "index":
#    1206             err_msg += "\n To use the index, pass it in directly as `df.index`."
# -> 1207         raise ValueError(err_msg)
#    1208 elif length and len(df_input[argument]) != length:
#    1209     raise ValueError(
#    1210         "All arguments should have the same length. "
#    1211         "The length of column argument `df[%s]` is %d, whereas the "
#    (...)
#    1218         )
#    1219     )
#
# ValueError: Value of 'hover_name' is not the name of a column in 'data_frame'. Expected one of ['Name', 'Household Income', 'Population', 'Median Age', 'Per Capita Income', 'Poverty Count', 'Total Work Force', 'Total Female Workforce', 'Total Female Did Not Work', 'Total Male Workforce', 'Total Male Did Not Work', 'Masters Attainment', 'Median Rent', 'state', 'Year', 'state_code', 'geometry', 'id', 'properties', 'Male DNW %', 'Female DNW %', 'DNW Delta', 'Poverty Rate'] but received: State
